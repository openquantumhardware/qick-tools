# %% [markdown]
# ### QICK Standard ZCU111 Firmware + FFT/Spectrum Analysis
#
# This firmware is a standard ZCU111 firmware (with less SGv6 though to make room for the BREAD Small logic) + BREAD Small chain. The BREAD small chain is a reduced FFT version (16k in place of 32k points) of the BREAD Real project.
#
# BREAD Small part: this part has one input ADC and one output DAC. ADC is connected to Tile 224 Channel 0. DAC is connected to Tile 229 Channel 2.
#
# There's an option to connect ADC_224_0 to a Readout path to capture data with the tProcessor.
#
# See examples to extract data from the different points.
#
# <!-- ![alt text](images/std_111_bread_small.png "Block Diagram") -->
# <!-- ![alt text](images/qick_tprocv2_111_fft_spectrum_diagram.png "Block Diagram") -->
# <img src="images/qick_diagrams-QICK_TPROCV2_111_FFT_SPECTRUM.drawio.png" alt="Placeholder" width="1200" height="1000">

# %%
import sys
import os
# print(sys.path)
# print(os.getcwd())
# sys.path.append(os.getcwd())

# Remote VSCode needs the current file path to be appended explicitly to find modules in files (os.getcwd() does not work)
# sys.path.append('/home/xilinx/jupyter_notebooks/qick-tools/qick_tprocv2_111_fft_spectrum/soft')
sys.path.append('../soft')

USE_LOCAL_QICK = True

QICK_WORKSPACE = "/home/dmartin2/qick_internal_b_51_fft"
QICK_TOOLS = QICK_WORKSPACE + "/qick-tools_b_6_fft"

if USE_LOCAL_QICK:
    import sys
    import os
    print(sys.path.insert(0,QICK_WORKSPACE + "/qick_lib"))
    print(sys.path.insert(0,QICK_TOOLS + "/qick_tprocv2_111_fft_spectrum/soft"))
    print(sys.path)
# Out:
# None
# None
# ['/home/dmartin2/qick_internal_b_51_fft/qick-tools_b_6_fft/qick_tprocv2_111_fft_spectrum/soft', '/home/dmartin2/qick_internal_b_51_fft/qick_lib', '/home/xilinx/jupyter_notebooks', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/share/pynq-venv/lib/python3.10/site-packages', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.10/dist-packages', '../soft']

# %%
# jupyter setup boilerplate
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy.fft import fftshift, fft

from qick import *
# the main program class
from qick.asm_v2 import AveragerProgramV2
# for defining sweeps
from qick.asm_v2 import QickSpan, QickSweep1D

print(qick.get_version())

# from qick.spectrum import SpectrumSoc, DualChain
from spectrum import SpectrumSoc
# from qick.fft_helpers import *
from fft_helpers import *

import pynq
pynq.pl_server.global_state.clear_global_state()
# Out:
# 0.2.375

# %%
USE_PYRO = False

if USE_PYRO:
    from qick.pyro import make_proxy
    # soc, soccfg = make_proxy(ns_host="pynq4x2.dhcp.fnal.gov", ns_port=8888, proxy_name="myqick")
    # soc, soccfg = make_proxy(ns_host="pynq216-6.dhcp.fnal.gov", ns_port=8888, proxy_name="myqick")
    soc, soccfg = make_proxy(ns_host="pynq111-4.dhcp.fnal.gov", ns_port=8888, proxy_name="myqick")
else:
    # soc = SpectrumSoc(bitfile='/home/dmartin2/fw/qick_tprocv2_111_fft_spectrum_251008_1/qick_111.bit')  # includes an axis_switch to select 4xADC input to spectrum signal path
    # soc = SpectrumSoc(bitfile='/home/dmartin2/fw/qick_tprocv2_111_fft_spectrum_251121_1/qick_111.bit')  # same as 251008_1 with ADC_224 switch to connect to readout path
    # soc = SpectrumSoc(bitfile='/home/dmartin2/fw/qick_tprocv2_111_fft_spectrum_251124_1/qick_111.bit')  # same as 251008_1 with ADC_224 switch to connect to readout path
    # soc = SpectrumSoc(bitfile='/home/dmartin2/fw/qick_tprocv2_111_fft_spectrum_251124_2/qick_111.bit')  # same as 251008_1 with ADC_224 switch to connect to readout path
    soc = SpectrumSoc(bitfile='/home/dmartin2/fw/qick_tprocv2_111_fft_spectrum_251126_1/qick_111.bit')  # same as 251124_2 with extra IQconstant at DAC_229_0
    soccfg = soc

print(soccfg)
# Out:
# QICK running on ZCU111, software version 0.2.375
#
# Firmware configuration (built Wed Nov 26 16:27:31 2025):
#
# 	Global clocks (MHz): tProc dispatcher timing 384.000, RF reference 204.800
# 	Groups of related clocks: [tProc core clock, tProc timing clock, DAC tile 0, DAC tile 1], [ADC tile 0, ADC tile 1, ADC tile 2]
#
# 	4 signal generator channels:
# 	0:	axis_signal_gen_v6 - fs=6144.000 Msps, fabric=384.000 MHz
# 		envelope memory: 16384 complex samples (2.667 us)
# 		32-bit DDS, range=6144.000 MHz
# 		DAC tile 0, blk 0 is DAC228_T0_CH0, or RF board DAC port 0
# 	1:	axis_signal_gen_v6 - fs=6144.000 Msps, fabric=384.000 MHz
# 		envelope memory: 16384 complex samples (2.667 us)
# 		32-bit DDS, range=6144.000 MHz
# 		DAC tile 0, blk 1 is DAC228_T0_CH1, or RF board DAC port 1
# 	2:	axis_signal_gen_v6 - fs=6144.000 Msps, fabric=384.000 MHz
# 		envelope memory: 16384 complex samples (2.667 us)
# 		32-bit DDS, range=6144.000 MHz
# 		DAC tile 0, blk 2 is DAC228_T0_CH2, or RF board DAC port 2
# 	3:	axis_signal_gen_v6 - fs=6144.000 Msps, fabric=384.000 MHz
# 		envelope memory: 16384 complex samples (2.667 us)
# 		32-bit DDS, range=6144.000 MHz
# 		DAC tile 0, blk 3 is DAC228_T0_CH3, or RF board DAC port 3
#
# 	3 constant-IQ outputs:
# 	0:	fs=6144.000 Msps
# 		DAC tile 1, blk 0 is DAC229_T1_CH0, or RF board DAC port 4
# 	1:	fs=6144.000 Msps
# 		DAC tile 1, blk 2 is DAC229_T1_CH2, or RF board DAC port 6
# 	2:	fs=6144.000 Msps
# 		DAC tile 1, blk 3 is DAC229_T1_CH3, or RF board DAC port 7
#
# 	2 readout channels:
# 	0:	axis_dyn_readout_v1 - configured by tProc output 4
# 		fs=4096.000 Msps, decimated=512.000 MHz, 32-bit DDS, range=4096.000 MHz
# 		axis_avg_buffer v1.2 (has edge counter, no weights)
# 		memory 16384 accumulated, 4096 decimated (8.000 us)
# 		triggered by tport 10, pin 0, feedback to tProc input 0
# 		ADC tile 2, blk 0 is ADC226_T2_CH0, or RF board ADC DC port 0
# 	1:	axis_dyn_readout_v1 - configured by tProc output 5
# 		fs=4096.000 Msps, decimated=512.000 MHz, 32-bit DDS, range=4096.000 MHz
# 		axis_avg_buffer v1.2 (has edge counter, no weights)
# 		memory 16384 accumulated, 4096 decimated (8.000 us)
# 		triggered by tport 11, pin 0, feedback to tProc input 1
# 		ADC tile 2, blk 2 is ADC226_T2_CH1, or RF board ADC DC port 1
#
# 	8 digital output pins:
# 	0:	PMOD0_0_LS
# 	1:	PMOD0_1_LS
# 	2:	PMOD0_2_LS
# 	3:	PMOD0_3_LS
# 	4:	PMOD0_4_LS
# 	5:	PMOD0_5_LS
# 	6:	PMOD0_6_LS
# 	7:	PMOD0_7_LS
#
# 	tProc: qick_processor ("v2") rev 27, core execution clock 192.000 MHz
# 		memories (words): program 4096, data 16384, waveform 1024
# 		external start pin: PMOD1_0_LS
# 		external stop pin: None
#
# 	MR buffer: 8192 samples (2.000 us), wired to readouts [0, 1]
#
# SPECTRUM configuration:
#
#
# 	Board: ZCU111
# 	Analysis 0:
# 		ADC tile 0, blk 0 is ADC224_T0_CH0, or RF board ADC AC port 0
# 		fs = 4096.0 MHz, Decimation    = 2
# 		PFB: fs = 256.0 MHz, fc = 128.0 MHz, 16 channels

# %%
# Start('Deb Debug Bridge Server if present
try:
    bridge = soc._get_block('debug_bridge_0')
    bridge.start_xvc_server(bufferLen=4096, serverAddress="0.0.0.0", serverPort=2542, reconnect=True, verbose=True)

except:
    print('debug blocks not found')
# Out:
# XVC server started

# %%
## Do not forget to stop the XVC server once you finish.
bridge = soc._get_block('debug_bridge_0')
bridge.stop_xvc_server()
# Out:
# XVC server stopped

# %%
#########################
### Define dual chain ###
#########################
# chain = DualChain(soc,soc['analysis'][0],soc['synthesis'][0])
# chain = DualChain(soc,soc['analysis'][0],soc['synthesis'][1])
chain = DualChain(soc,soc['analysis'][0],soc['synthesis'][2])

# %%
# import xrfdc 

# # Get ADC block associated with the Analysis chain
# adc_block_0 = soc.rf._get_block('adc', chain.analysis.dict['chain']['adc']['id'])

# # save current setting of ADC Mixer
# mixer_settings = adc_block_0.MixerSettings

# # # Configure Coarse Mixer
# # mixer_settings['CoarseMixFreq'] = 8
# # mixer_settings['MixerType'] = 1
# # mixer_settings['MixerMode'] = 3

# # Configure Fine Mixer
# mixer_settings['MixerType'] = 2
# mixer_settings['Freq'] = 0.0

# # Update Mixer changes
# adc_block_0.MixerSettings = mixer_settings
# adc_block_0.UpdateEvent(xrfdc.EVENT_MIXER)

# %%
##########################################
### Simple Sine Loop-back (ADC output) ###
##########################################

# NOTE: ADC raw output is the mix of input tone with -Fs/4 mixer frequency

# fout = np.random.randint(0,1000)
fout = 128 + 1
# fout = 128*7 + 1
# fout = 1000
print("fout: %d"%(fout))
chain.set_tone(f=fout,g=0.5,verbose=True)

# Select ADC axis_switch
soc.adc_fft_sel(0)  ## Select ADC_224_CH0: 0 - 1GHz
# soc.adc_fft_sel(1)  ## Select ADC_224_CH1: 0 - 1GHz
# soc.adc_fft_sel(2)  ## Select ADC_225_CH0: 1 - 4GHz
# soc.adc_fft_sel(3)  ## Select ADC_225_CH1: 1 - 4GHz

# Get data.
[xi,xq] = chain.get_data_adc()
x = xi + 1j*xq

# # (for Debug)
# # plt.figure(0)
# # plt.plot(xi[:100])
# # plt.plot(xq[:100])


# # (for Debug)
# # Select appropriate PFB channel
# # Get data.
# [xi,xq] = chain.get_bin_pfb(fout)
# x = xi + 1j*xq
# # plt.figure(1)
# # plt.plot(xi[:100])
# # plt.plot(xq[:100])


# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Time domain signal.
n = np.arange(len(x))
t = n/chain.fs
plt.figure(2,dpi=100)
plt.plot(1000*t,np.real(x))
plt.xlabel("t [ns]");
plt.ylabel("Amplitude [mV]");
plt.xlim([0,100]);

# Spectrum.
w = np.hanning(len(x))
Aw = len(w)/np.sum(w)
xw = Aw*x*w
Y = fftshift(fft(xw)/len(xw))
F = np.linspace(0,chain.fs,len(Y))

# Normalize to dBm.
R = 50
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1,Y1));

plt.figure(1,dpi=100)
plt.plot(F,Y)
plt.plot(F1,Y1,'r*');
plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
plt.xlim([0,2000])
plt.ylim([-120,-10])

# Time domain signal.
n = np.arange(len(x))
t = n/chain.fs
plt.figure(2,dpi=100)
plt.plot(1000*t,np.real(x))
plt.xlabel("t [ns]");
plt.ylabel("Amplitude [mV]");
plt.xlim([0,100]);
# Out:
# fout: 129
# F1 = 129.004, Y1 = -17.496

# %%
# # (for Debug)
# # Plot ADC buffer at different frequencies through the spectrum

# plt.figure(figsize=[25,10])

# L = 8

# for i in range(L):

#     fout = 100 + (25 * i)
#     fout = 150 * i
#     print("fout: %d"%(fout))
#     chain.set_tone(f=fout,g=1.0,verbose=False)

#     # Get data.
#     [xi,xq] = chain.get_data_adc()
#     x = xi + 1j*xq

#     plt.subplot(4,L//4,i+1)
#     plt.plot(xi[:100])
#     plt.plot(xq[:100])

# %%
##########################################
### Simple Sine Loop-back (PFB output) ###
##########################################

# fout = np.random.randint(0,1000)
fout = 30
print("fout: %d"%(fout))
chain.set_tone(f=fout,g=1.0,verbose=True)

# Compute channel center frequency.
CH = chain.analysis.freq2ch(fout)
print('CH: %0d'%(CH))
FC = chain.analysis.ch2freq(CH)
print('FC: %0.3f'%(FC))

# If the tone amplitude is too high, it will saturate the PFB, need to adjust QOUT output
# Adjust output bits of PFB (0 means 16 lsbs, > 0 shifts data to right -> divides value to increase range)
chain.analysis.qout(2)

# Bypass DDS and CIC
chain.set_ddscic_outsel(data="input", cic="no")

# Get data.
[xi,xq] = chain.get_bin_pfb(fout)
x = xi + 1j*xq
plt.figure(0)
plt.plot(xi[:100])
plt.plot(xq[:100])
# plt.figure()
# plt.plot(np.real(x[:100]))


# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Spectrum.
w = np.hanning(len(x))
Aw = len(w)/np.sum(w)
xw = Aw*x*w
Y = fftshift(fft(xw)/len(xw))
F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

# Normalize to dBm.
R = 50
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1+FC,Y1));

plt.figure(3,dpi=150)
plt.plot(F+FC,Y)
plt.plot(F1+FC,Y1,'r*');
plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# fout: 30
# CH: 8
# FC: 0.000
# F1 = 30.002, Y1 = -8.320

# %%
##########################################
### Channels Side-by-Side (PFB output) ###
##########################################
# Channels to plot.
K = np.arange(chain.nch)

# Frequency and amplitude vectors.
FF = []
AA = []

plt.figure(figsize=[25,10])

for KK in K:
    # Channel center frequency.
    fck = chain.analysis.ch2freq(KK)
    
    print("Iteration K = %d; Freq: %f" % (KK, fck))  

    # Get data.
    [xi,xq] = chain.get_bin_pfb(fck+1)
    x = xi + 1j*xq

    plt.subplot(2,8,KK+1)
    plt.plot(xi[:100])


plt.figure(4, dpi=150)

for KK in K:
    print("Iteration K = %d" %KK)  
    # Channel center frequency.
    fck = chain.analysis.ch2freq(KK)
    
    # Get data.
    [xi,xq] = chain.get_bin_pfb(fck+1)
    x = xi + 1j*xq

    # ADU to V.
    # 500mV --> 2^15
    x = x*0.5/2**15

    # Spectrum.
    w = np.hanning(len(x))
    Aw = len(w)/np.sum(w)
    xw = Aw*x*w
    Y = fftshift(fft(xw)/len(xw))
    F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

    # Normalize to dBm.
    R = 50;
    Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
    
    Fk = F+fck
    plt.plot(Fk,Y)

plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# Iteration K = 0; Freq: 1024.000000
# Iteration K = 1; Freq: 1152.000000
# Iteration K = 2; Freq: 1280.000000
# Iteration K = 3; Freq: 1408.000000
# Iteration K = 4; Freq: 1536.000000
# Iteration K = 5; Freq: 1664.000000
# Iteration K = 6; Freq: 1792.000000
# Iteration K = 7; Freq: 1920.000000
# Iteration K = 8; Freq: 0.000000
# Iteration K = 9; Freq: 128.000000
# Iteration K = 10; Freq: 256.000000
# Iteration K = 11; Freq: 384.000000
# Iteration K = 12; Freq: 512.000000
# Iteration K = 13; Freq: 640.000000
# Iteration K = 14; Freq: 768.000000
# Iteration K = 15; Freq: 896.000000
# Iteration K = 0
# Iteration K = 1
# Iteration K = 2
# Iteration K = 3
# Iteration K = 4
# Iteration K = 5
# Iteration K = 6
# Iteration K = 7
# Iteration K = 8
# Iteration K = 9
# Iteration K = 10
# Iteration K = 11
# Iteration K = 12
# Iteration K = 13
# Iteration K = 14
# Iteration K = 15

# %%
###########################################
### Simple Sine Loop-back (XFFT output) ###
###########################################

fout = 100
# fout = np.random.randint(0,1000)
print("fout: %d"%(fout))
chain.set_tone(fout,g=1.0, verbose=True)

# Compute channel center frequency.
FC = chain.analysis.ch2freq(chain.analysis.freq2ch(fout))

# Get data.
[xi,xq] = chain.get_bin_xfft(fout)
x = xi + 1j*xq

# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Scale by FFT length.
x = x/chain.FFT_N

# Spectrum.
Y = fftshift(x)
F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

# Normalize to dBm.
R = 50;
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1+FC,Y1));

plt.figure(5,dpi=150)
plt.plot(F+FC,Y)
plt.plot(F1+FC,Y1,'r*');
plt.xlabel("F [MHz]");
# Out:
# fout: 100
# F1 = 100.006, Y1 = -5.674

# %%
###########################################
### Channels Side-by-Side (XFFT output) ###
###########################################
# Channels to plot.
K = np.arange(chain.nch)

plt.figure(6,dpi=150)

# Frequency and amplitude vectors.
FF = []
AA = []
for KK in K:
    print("Iteration K = %d" %KK)
    # Channel center frequency.
    fck = chain.analysis.ch2freq(KK)
    
    # Get data.    
    [xi,xq] = chain.get_bin_xfft(fck+1)
    x = xi + 1j*xq

    # ADU to V.
    # 500mV --> 2^15
    x = x*0.5/2**15
    
    # Scale by FFT length.
    x = x/chain.FFT_N

    # Spectrum.
    Y = fftshift(x)
    F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

    # Normalize to dBm.
    R = 50
    Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
    
    Fk = F+fck
    plt.plot(Fk,Y)

plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# Iteration K = 0
# Iteration K = 1
# Iteration K = 2
# Iteration K = 3
# Iteration K = 4
# Iteration K = 5
# Iteration K = 6
# Iteration K = 7
# Iteration K = 8
# Iteration K = 9
# Iteration K = 10
# Iteration K = 11
# Iteration K = 12
# /tmp/ipykernel_39406/1407343824.py:34: RuntimeWarning: divide by zero encountered in log10
#   Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
# /tmp/ipykernel_39406/1407343824.py:34: RuntimeWarning: divide by zero encountered in log10
#   Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
# Iteration K = 13
# Iteration K = 14
# Iteration K = 15

# %%
##########################################
### Simple Sine Loop-back (ACC output) ###
##########################################

fout = 800
# fout = np.random.randint(0,1000)
print("fout: %d"%(fout))
chain.set_tone(fout,g=1.0, verbose=True)

# Number of averages.
N = 10

# Get data.
x = chain.get_data_acc(N)

# # ADU to V.
# # 500mV --> 2^15
# x = x*(0.5/2**15)**2

# Scale by FFT length.
x = x/(chain.FFT_N)**2

# Spectrum.
Y = fftshift(x)
F = np.linspace(0,chain.fs,len(x))

# Normalize to dBm.
R = 50
Y = 10*np.log10((np.sqrt(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1,Y1));

plt.figure(7,dpi=150)
plt.plot(F,Y)
plt.plot(F1,Y1,'r*');
plt.xlabel("F [MHz]");
plt.xlim([0,1000]);
plt.ylim([-10,100]);

print('FFT Resolution: {} kHz'.format(1000*soc['analysis'][0]['fs_ch']/chain.FFT_N))
# Out:
# fout: 800
# F1 = 800.006, Y1 = 88.431
# FFT Resolution: 15.625 kHz

# %%
###############################
### Single Channel Zoom FFT ###
###############################
# Output frequency.
fout = 270
chain.set_tone(f=fout, g=0.25)

# Compute channel center frequency.
pfb_channel = chain.analysis.freq2ch(fout)
FC = chain.analysis.ch2freq(pfb_channel)
print("pfb_channel: %d / FC: %d"%(pfb_channel,FC))

# # DEBUG
## soc.axis_ddscic_v3_0.ddsfreq(f=10e6)
## soc.axis_ddscic_v3_0.outsel(data="dds", cic="no")
# chain.set_ddscic_ddsfreq(f=10e6)
# chain.set_ddscic_outsel(data="dds", cic="no")
# [xi,xq] = chain.get_bin_pfb(fout, verbose=True)
# plt.figure()
# plt.plot(xi[:100])

# # DEBUG
## soc.axis_ddscic_v3_0.outsel(data="input", cic="no")
# chain.set_ddscic_outsel(data="input", cic="no")
# [xi,xq] = chain.get_bin_pfb(fout, verbose=True)
# plt.figure()
# plt.plot(xi[:100])


# DDS + CIC configuration.
D=200
chain.set_ddscic_outsel(data="product", cic="yes")
chain.set_ddscic_decimation(D)
chain.set_ddscic_ddsfreq(f=14e6-200e3)
chain.set_ddscic_set_qprod(14) # quantization range for product 0-16
[xi,xq] = chain.get_bin_pfb(fout, verbose=True)
plt.figure()
plt.plot(xi[:100])

# Get data.
# x = soc.axis_accumulator_1.single_shot(10)
x = chain.get_data_acc_zoom(10)

# Sampling frequency.
fs = chain.analysis.dict['chain']['fs_ch']/chain.get_ddscic_decimation()
F = np.linspace(-fs/2,fs/2,len(Y))


# ADU to V.
# 500mV --> 2^15
x = x*(0.5/2**15)**2

# Scale by window gain.
#x = x*(soc.axis_wxfft_65536_0.Aw)**2*(2**16)**2

# Scale by FFT length.
x = x/(chain.WFFT_N)**2

# Spectrum.
Y = x
F = np.linspace(-fs/2,fs/2,len(Y))

# Normalize to dBm.
R = 50
Y = 10*np.log10((np.sqrt(Y)**2)/(2*R*1e-3))

# Max.
[F1,Y1] = findPeak(F,Y)
print('Peek found at F1 = {:.3f}, Y1 = {:.3f}'.format(F1+FC,Y1))

plt.figure(dpi=150)
plt.plot(F+FC,Y)
plt.plot(F1+FC,Y1,'r*')
plt.xlabel("F [MHz]")
plt.ylabel("Power [dBm]")

#print('FFT Resolution: {} Hz'.format(1000*1000*fs/soc.acc_zoom.FFT_N))
print('FFT Resolution: {} Hz'.format(1000*1000*fs/chain.WFFT_N))
# Out:
# pfb_channel: 10 / FC: 256
# AbsPfbAnalysis: f = 270 MHz, fd = -754.0 MHz, k = 10
# Peek found at F1 = 256.200, Y1 = -25.251
# FFT Resolution: 19.53125 Hz

# %% [markdown]
# # Now let's play a little with the standard part of the FW.

# %% [markdown]
# ### Hardware Configuration
#
# You should cable the board in loopback, connecting one DAC to one ADC. You can set appropriate generator and readout numbers in the cell below, which will be used in `res_ch` and `ro_chs` entries in the program dictionaries below.
#
# For example, for a ZCU111 you might connect DAC228_T0_CH0_P to ADC226_T2_CH0_P (these are the labels on the XM500 balun board). The DAC and ADC lists tell you that these are DAC tile 0, block 0, and ADC tile 2, block 0. The generator and readout lists tell you that these are driven by generator 0 and readout 0, and your QICK programs will reference those IDs.

# %%
GEN_CH = 0
RO_CH = 0
TRIG_TIME = 0.30
FREQ = 500

# This selects the default ADC_226
# adc_224_0_sw.sel(slv=1,mst=0)
soc.adc_224_0_sw_sel(use_adc_224_0=False)

class MultiPulseProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch = cfg['ro_ch']
        gen_ch = cfg['gen_ch']
        
        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        ramp_len = 0.2
        self.add_gauss(ch=gen_ch, name="ramp", sigma=ramp_len/10, length=ramp_len, even_length=True)
        
        self.add_pulse(ch=gen_ch, name="myflattop", ro_ch=ro_ch, 
                       style="flat_top", 
                       envelope="ramp", 
                       freq=cfg['freq'], 
                       length=0.1,
                       phase=0,
                       gain=1.0, 
                      )

        self.add_pulse(ch=gen_ch, name="mygaus", ro_ch=ro_ch, 
                       style="arb", 
                       envelope="ramp", 
                       freq=cfg['freq'], 
                       phase=0,
                       gain=1.0, 
                      )

        self.add_pulse(ch=gen_ch, name="myconst", ro_ch=ro_ch, 
                       style="const", 
                       length=0.2, 
                       freq=cfg['freq'], 
                       phase=0,
                       gain=1.0,
                      )

        self.add_pulse(ch=gen_ch, name="myflattop2", ro_ch=ro_ch, 
                       style="flat_top", 
                       envelope="ramp", 
                       freq=cfg['freq'], 
                       length=0.1,
                       phase=90,
                       gain=1.0, 
                      )

        self.add_readoutconfig(ch=ro_ch, name="myro", freq=cfg['freq'], gen_ch=gen_ch)
        # send the config to the dynamic RO
        self.send_readoutconfig(ch=ro_ch, name="myro", t=0)
        
    def _body(self, cfg):
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])

        self.pulse(ch=cfg['gen_ch'], name="myflattop", t=0)
        self.pulse(ch=cfg['gen_ch'], name="mygaus", t=0.4)
        self.pulse(ch=cfg['gen_ch'], name="myconst", t=0.8)
        self.pulse(ch=cfg['gen_ch'], name="myflattop2", t=1.2)
        self.pulse(ch=cfg['gen_ch'], name="mygaus", t=1.6)
        
config = {'gen_ch': GEN_CH,
          'ro_ch': RO_CH,
          'freq': FREQ,
          'trig_time': TRIG_TIME,
          'ro_len': 2.0,
         }

prog = MultiPulseProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

# iq_list = prog.acquire_decimated(soc, soft_avgs=10)
iq_list = prog.acquire_decimated(soc)
t = prog.get_time_axis(ro_index=0)
t = t / 2.0

plt.plot(t, iq_list[0][:,0], label="I value")
plt.plot(t, iq_list[0][:,1], label="Q value")
plt.plot(t, np.abs(iq_list[0].dot([1,1j])), label="magnitude")
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Text(0.5, 0, 'us')

# %% [markdown]
# # Switch the readout ADC to use the FFT Path ADC

# %%
GEN_CH = 0
RO_CH = 0
TRIG_TIME = 0.30
FREQ = 250

RO_ADC_224 = True   # Use ADC_224_0 for readout channel 0
# RO_ADC_224 = False  # Use ADC_226_0 for readout channel 0

# Select which ADC connects to the CH0-readout-path
if RO_ADC_224:
    fout = FREQ
    print("fout: %d"%(fout))
    chain.set_tone(f=fout,g=0.25)

    # Select PFB_CH_SEL of frequency range (not the best function to use but works)
    chain.get_bin_pfb(fout)

    # Compute channel center frequency.
    pfb_channel = chain.analysis.freq2ch(fout)
    FC = chain.analysis.ch2freq(pfb_channel)
    # print("pfb_channel: %d / FC: %d"%(pfb_channel,FC))

    # Configure ADC switch to select ADC_224_0 for readout path.
    ## slv=0 : ADC_224_0, slv=1: ADC_226_0
    # adc_224_0_sw.sel(slv=0,mst=0)
    soc.adc_224_0_sw_sel(use_adc_224_0=True)

    f_ddscic = FREQ - FC
    print("DDSCIC Mixer Frequency: %d MHz"%(f_ddscic))

    # DDS + CIC configuration.
    D=1
    # soc.axis_ddscic_v3_0.set_qprod(14) # quantization range for product 0-16
    chain.set_ddscic_outsel(data="product", cic="no")
    chain.set_ddscic_decimation(D)
    chain.set_ddscic_ddsfreq(f=f_ddscic*1e6)    # scale to MHz!!!

    # # DEBUG
    # chain.set_ddscic_outsel(data="dds", cic="no")
    # [xi,xq] = chain.get_bin_pfb(fout, verbose=True)
    # plt.figure()
    # plt.plot(xi[:20])

else:
    # This selects the default ADC_226
    # adc_224_0_sw.sel(slv=1,mst=0)
    soc.adc_224_0_sw_sel(use_adc_224_0=False)


class MultiPulseProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch = cfg['ro_ch']
        gen_ch = cfg['gen_ch']
        
        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_readoutconfig(ch=ro_ch, name="myro", freq=cfg['freq'], gen_ch=gen_ch)
        # send the config to the dynamic RO
        self.send_readoutconfig(ch=ro_ch, name="myro", t=0)
        
    def _body(self, cfg):
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])
 
config = {'gen_ch': GEN_CH,
          'ro_ch': RO_CH,
          'freq': FREQ,
          'trig_time': TRIG_TIME,
          'ro_len': 2.0,
         }

prog = MultiPulseProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

# One shot Measurement
iq_list = prog.acquire_decimated(soc, rounds=1)
# t = prog.get_time_axis(ro_index=0)
t = np.arange(len(iq_list[0])) / chain.fs

plt.figure()
plt.plot(t, iq_list[0][:,0], label="I value")
plt.plot(t, iq_list[0][:,1], label="Q value")
plt.plot(t, np.abs(iq_list[0].dot([1,1j])), label="magnitude")
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us")

# Averaged Measurement
iq_list = prog.acquire_decimated(soc, rounds=100)
# t = prog.get_time_axis(ro_index=0)
t = np.arange(len(iq_list[0])) / chain.fs

plt.figure()
plt.plot(t, iq_list[0][:,0], label="I value")
plt.plot(t, iq_list[0][:,1], label="Q value")
plt.plot(t, np.abs(iq_list[0].dot([1,1j])), label="magnitude")
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us")
# Out:
# fout: 250
# DDSCIC Mixer Frequency: -6 MHz
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Text(0.5, 0, 'us')
